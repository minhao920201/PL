# %% [markdown]
# # 由於資料量過大，無法顯示完整內容，[請點擊此處前往jupyter官方網站](https://nbviewer.org/)，複製本篇網址貼上即可完整瀏覽

# %%
import json #載入json模組
test = open('JSONcrawler.json',encoding="utf8") #開檔
Data = json.load(test) #反序列化(decode)
#把蒐集到的資料印出來
temp = Data.get('Article') #取得 key = "Title" 的 value 
temp #印出 key = "Title" 的 value
# Out:
# [{'標題': 'Line 的聊天記錄不見 又沒備份怎麼辦',
#   '標籤': ['line'],
#   '詢問時間': '2022-11-28',
#   '瀏覽次數': '163',
#   '內文': 'EOLLine 不小心被強制登出 結果沒有備份EOL聊天紀錄都不見了EOL怎麼樣才可以恢復之前的對話紀錄EOL查了網路上的軟件EOL也沒辦法解決EOL'},
#  {'標題': 'linux apt中沒有kernel-package',
#   '標籤': ['apt', 'apt-get install error', 'linux', 'linux kernel'],
#   '詢問時間': '2022-11-28',
#   '瀏覽次數': '102',
#   '內文': 'EOL想使用kernel-package，結果發生這個錯誤EOL查了之後發現apt裡沒有EOLEOLapt也已經update跟upgrade過了，還是失敗，想問還有什麼解決辦法EOL'},
#  {'標題': '求助大神，關於檔案讀取問題',
#   '標籤': ['陣列', 'txt文字檔', 'c++'],
#   '詢問時間': '2022-11-28',
#   '瀏覽次數': '112',
# ...

# %%
import jieba
import jieba.analyse
jieba.analyse.set_stop_words('stopwords.txt')
index = 0
li_jieba = []
for documents in temp:
    seg_list = jieba.analyse.extract_tags(documents['內文'], 150)
    li_jieba.append(seg_list)

# %%
li_jieba
# Out:
# [['EOL',
#   '紀錄',
#   'EOLLine',
#   '強制',
#   '結果',
#   '沒有',
#   '備份',
#   '不見',
#   '怎麼樣',
#   '查了網',
#   '軟件',
#   '辦法',
#   '解決',
#   '登出',
#   '聊天',
#   '小心',
#   '路上',
#   '之前',
#   '可以'],
#  ['EOL',
#   'kernel',
#   'package',
#   '結果',
#   '發生',
#   '這個',
#   '錯誤',
#   '之後發現',
#   'apt',
#   '裡沒有',
#   'EOLEOLapt',
#   '已經',
#   'update',
#   'upgrade',
#   '過了',
#   '還是',
#   '失敗',
#   '想問',
#   '還有',
#   '什麼',
#   '解決',
#   '辦法',
#   '使用'],
#  ['EOL',
#   'int',
#   'EOLinfile',
#   '讀取',
#   'txt',
#   '數據',
#   '陣列',
#   'includeEOL',
#   'EOLconst',
#   '516',
#   'data',
#   'EOLfor',
#   '++',
#   '問問',
#   '甚麼',
#   '某幾欄',
#   '順利',
#   '多筆',
#   '無法',
#   '將陣列',
#   '小陣列',
#   '進行後續',
#   '運算',
#   'code',
#   '麻煩',
#   '謝謝',
#   'includeEOLusing',
#   'namespace',
#   'std',
#   'EOLint',
#   'main',
#   'double',
#   'EOLifstream',
#   'infile',
#   'open',
#   'benzene1',
#   'close',
#   'EOLsystem',
#   'pause',
#   'EOLreturn',
#   '大神',
#   '需要',
#   '形成',
# ...

# %%
#印出不同"標籤"出現次數
dic = {} #紀錄下面取得的不同"標籤"出現次數
for i in temp: #從 list 中一個一個列舉出 dict
    #print(li['標籤'])
    for j in i['標籤']: #列舉出每個 key = "標籤" 的 value
        dic[j] = dic.get(j,0)+1 #檢查"標籤"中的每個字串是否出現在 dic 中。如果沒出現，則加入 dic 裡，並使其 value=1 ; 否則已經出現就將其 value+1
dic #利用dic印出不同"標籤"出現次數
# Out:
# {'line': 23,
#  'apt': 1,
#  'apt-get install error': 1,
#  'linux': 71,
#  'linux kernel': 1,
#  '陣列': 8,
#  'txt文字檔': 3,
#  'c++': 29,
#  '#平板': 1,
#  '#小米': 1,
#  '#網路#ip': 2,
#  '#紅米': 1,
#  '#andriod': 1,
#  'javascript': 181,
#  'js': 54,
#  'jquery': 35,
#  'colaboratory': 2,
#  '程式編輯': 1,
#  '程式編成': 1,
#  'html': 105,
#  'ansible': 3,
#  'mysql': 90,
#  'windows': 56,
#  '系統管理': 2,
#  'system': 4,
#  'pxe': 1,
#  '#excel #vba': 22,
#  'm.2 ssd': 2,
#  'windows10': 7,
#  '雙使用者': 1,
#  'python': 314,
#  'list': 8,
#  '差異': 1,
#  'hp switch': 2,
#  'vba': 46,
#  'marco': 1,
#  'excel': 128,
#  'vb': 4,
#  'excel vba': 54,
#  'ip': 16,
#  'vpn': 24,
#  'nas': 20,
#  'volume': 1,
#  'k8s': 7,
#  'kubernetes': 12,
#  'nfs': 4,
#  'ad server': 2,
#  'logon script': 1,
#  'firewall': 12,
#  'sophos': 2,
#  '徵才': 1,
#  'linebotsdk': 2,
#  '#googlecloudstorage': 1,
#  'win7bios': 1,
#  '磁碟鏡像': 2,
#  '硬碟備份': 1,
#  'sourcetree': 1,
#  'git': 26,
#  '#新手求指導': 26,
#  'a紀錄': 1,
#  '自管': 1,
# ...

# %%
#利用迴圈顯示出標籤次數大於10的"標籤"
for i in dic:
    if dic[i]>10:
        print(i,":",dic[i])
# Out:
# line : 23
# linux : 71
# c++ : 29
# javascript : 181
# js : 54
# jquery : 35
# html : 105
# mysql : 90
# windows : 56
# #excel #vba : 22
# python : 314
# vba : 46
# excel : 128
# excel vba : 54
# ip : 16
# vpn : 24
# nas : 20
# kubernetes : 12
# firewall : 12
# git : 26
# #新手求指導 : 26
# mvc : 13
# iis : 16
# asp.net mvc : 41
# office : 13
# android : 34
# android studio : 23
# centos : 11
# r : 13
# sql : 121
# outlook : 27
# wifi : 13
# 網路 : 23
# hyper-v : 22
# ad : 44
# java : 94
# apache : 21
# php : 115
# router : 12
# #python : 27
# 網路架構 : 21
# line messaging api : 16
# line bot : 24
# python3 : 95
# pandas : 15
# wordpress : 21
# ssl憑證 : 18
# 網域 : 12
# win10 : 11
# c# : 182
# c#初學攻略心法 : 11
# 資料庫 : 26
# selenium : 21
# ubuntu : 30
# linq : 12
# windows 10 : 22
# mis : 21
# c : 34
# vscode : 29
# powershell : 21
# json : 26
# ios : 18
# ms sql : 39
# google : 13
# 爬蟲 : 13
# #html : 12
# docker : 29
# css : 62
# dns : 26
# fortigate : 35
# app : 13
# django : 26
# react : 45
# ...

# %% [markdown]
# # 製作長條圖

# %%
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

#把dic中的key和value抽取出來，以便下方製作圖使用
li_key = []
li_value = []
for i in dic:
    if dic[i]>10:
        li_key.append(i)
        li_value.append(dic[i])

#把網路上下載的字體加入
myfont = FontProperties(fname=r'./NotoSerifTC-Black.otf')

#設定圖片輸出的資訊
plt.figure(figsize=(20,20))
plt.title("Top Question")
plt.xlabel("Tag")
x = range(len(li_key))
plt.xticks(rotation=30,ha = "right")
plt.ylabel("Frequency")
plt.bar(li_key,li_value)
plt.xticks(x,li_key,fontproperties=myfont)
plt.savefig("Top Questions Chart")
plt.show()

# %% [markdown]
# # 製作文字雲

# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud

import numpy as np
mask = np.array(Image.open("it.jpg"))
font = "C:\Windows\Fonts\MSJH.TTC"

wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(dic)

plt.figure(figsize=(20,20))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("Word Cloud")
plt.show()
