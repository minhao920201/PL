# %%
import pandas as pd
data = pd.read_csv("IT_data.csv")
data.head()
# Out:
#                       文章標題       標籤   詢問日期
# 0                  git 沒反應      git  9月24日
# 1                  git 沒反應   github  9月24日
# 2  tableau 無法自動更新來源excel資料  tableau  9月24日
# 3              字典列表匯出excel    大神幫幫我  9月24日
# 4              字典列表匯出excel  python3  9月24日

# %%
date = data.drop_duplicates(subset=["詢問日期"])
date
# Out:
#                                                   文章標題  \
# 0                                              git 沒反應
# 24   如何 在 android studio accessibility service 編寫 設...
# 71                                      python學生程式設計問題
# 105                                            製作APP疑問
# 136                                       Mesh路由器 網頁認證
# 173                                             C語言金字塔
# 200                     vscode 和container建立ssh 連線失敗(急)
#
#                                        標籤   詢問日期
# 0                                     git  9月24日
# 24   android studio accessibility service  9月23日
# 71                                python3  9月22日
# 105                                   app  9月21日
# 136                                 xampp  9月20日
# 173                                     c  9月19日
# 200                                vscode  9月18日

# %%
first_date = data[data["詢問日期"]=="9月24日"]
second_date = data[data["詢問日期"]=="9月23日"]
third_data = data[data["詢問日期"]=="9月22日"]
first_three_date = pd.concat([first_date,second_date,third_data],axis=0)
first_three_date
# Out:
#                                 文章標題                                     標籤  \
# 0                            git 沒反應                                    git
# 1                            git 沒反應                                 github
# 2            tableau 無法自動更新來源excel資料                                tableau
# 3                        字典列表匯出excel                                  大神幫幫我
# 4                        字典列表匯出excel                                python3
# ..                               ...                                    ...
# 100             【PYTHON】請問如何避免內容重複抓取                                 python
# 101  VS2022多個projects在單一solution分開執行                     visual studio 2022
# 102                             SGD                                    深度學習
# 103                             SGD   stochastic gradient descent algorithm
# 104        Google Apps Script 速度優化問題                google apps script(gas)
#
#       詢問日期
# 0    9月24日
# 1    9月24日
# 2    9月24日
# ...

# %%
py = data[data["標籤"]=="python"]
py
# Out:
#                           文章標題      標籤   詢問日期
# 44                     顯示出重複字串  python  9月23日
# 100       【PYTHON】請問如何避免內容重複抓取  python  9月22日
# 149          webdriver問題，爬不出照片  python  9月20日
# 202                 計算list多維數量  python  9月18日
# 210  python: sql 將同筆資料寫入兩個不同表單  python  9月18日
