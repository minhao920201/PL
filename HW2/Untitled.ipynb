# %%
import json #載入json模組

# %%
test = open('csvjson.json',encoding="utf8") #開檔
Data = json.load(test) #反序列化(decode)
print(type(Data)) #印出 Data 的格式
# Out:
# <class 'dict'>

# %%
Data.items() #印出所有 Data 裡面的 key 和 value
# Out:
# dict_items([('Title', [{'文章標題': 'git 沒反應', '標籤': ['git', 'github'], '詢問日期': '9月24日'}, {'文章標題': 'tableau 無法自動更新來源excel資料', '標籤': ['tableau'], '詢問日期': '9月24日'}, {'文章標題': '字典列表匯出excel', '標籤': ['大神幫幫我', 'python3', '走不出新手村', '拜託'], '詢問日期': '9月24日'}, {'文章標題': 'Excel 如何回傳一組可變的地址範圍，藉此針對該範圍進行數據查找。(修正問題描述)', '標籤': ['excel', 'address', 'data', 'difficult：)'], '詢問日期': '9月24日'}, {'文章標題': '在 Mac OS 的 Android Studio 手機模擬器無法開機問題', '標籤': ['android studio', 'android', '手機模擬器', 'mac', 'mac os'], '詢問日期': '9月24日'}, {'文章標題': '電腦不時定格 需要手動重啟 是哪裡出問題了?', '標籤': ['當機', '電腦當機', '畫面死當', 'cpu過熱', '電源供應器'], '詢問日期': '9月24日'}, {'文章標題': 'PCIe, Ethernet & GPU的Bottleneck', '標籤': ['bottleneck', 'bandwidth', 'gpu'], '詢問日期': '9月24日'}, {'文章標題': '如何 在 android studio accessibility service 編寫 設定數字鍵 最後在APP外面 按下數字鍵 回應訊息', '標籤': ['android studio accessibility service'], '詢問日期': '9月23日'}, {'文章標題': '如何讓grid item根據剩餘vh自動填滿的高度?', '標籤': ['css', 'grid', 'flex', 'webdesign'], '詢問日期': '9月23日'}, {'文章標題': '0fdffffffffffff', '標籤': ['軟體工程師'], '詢問日期': '9月23日'}, {'文章標題': '可以問一下 vagrant 這兩種 provider 差在哪', '標籤': ['vagrant'], '詢問日期': '9月23日'}, {'文章標題': 'ubuntu 20讀取不到 主機板RAID1', '標籤': ['raid', 'linux'], '詢問日期': '9月23日'}, {'文章標題': 'Adobe AI & AE 權限問題,無法開啟', '標籤': ['#adobe', '#adobe illustrator', '#adobe after effects'], '詢問日期': '9月23日'}, {'文章標題': '開源的網頁問卷調查系統推薦', '標籤': ['survey'], '詢問日期': '9月23日'}, {'文章標題': '開源的網頁問卷調查系統推薦', '標籤': ['limesurvey'], '詢問日期': '9月23日'}, {'文章標題': '機房冷氣故障待維修，請教下應急處理', '標籤': ['機房', '散熱', '冷氣故障'], '詢問日期': '9月23日'}, {'文章標題': 'VBScript是否有涵式可判斷MSSQL的錯誤', '標籤': ['@vbs', '@asp', '@mssql'], '詢問日期': '9月23日'}, {'文章標題': '顯示出重複字串', '標籤': ['python', '數據分析'], '詢問日期': '9月23日'}, {'文章標題': 'AD錯誤訊息-本機系統 的自動憑證註冊無法註冊 網域控制站 憑證 (0x80070005) 存取被拒。', '標籤': ['ad', 'windows server 2003'], '詢問日期': '9月23日'}, {'文章標題': '[PHP][javascript]定位失效', '標籤': ['#id定位', '#php', '#javascript', '#line分享'], '詢問日期': '9月23日'}, {'文章標題': '想把 powershell 的 ctrl+v 的貼上功能停用，卻遇到權限問題(已解決)', '標籤': ['powershell', 'ctrl+v', '停用'], '詢問日期': '9月23日'}, {'文章標題': 'html 如何即時檢測到input裡有東西輸入', '標籤': ['html', 'javascript'], '詢問日期': '9月23日'}, {'文章標題': '請問有甚麼用arduino做溫室加溫的方法', '標籤': ['加溫', 'arduino', 'arduino加溫控制', '溫室', '致冷晶片'], '詢問日期': '9月23日'}, {'文章標題': 'Windows的工作排程器執行無反應', '標籤': ['windows', '#工作排程器', 'bat批次檔'], '詢問日期': '9月23日'}, {'文章標題': 'sim卡wifi', '標籤': ['sim卡wifi'], '詢問日期': '9月23日'}, {'文章標題': 'vmware migration issue', '標籤': ['vmware', 'netapp', 'migration'], '詢問日期': '9月23日'}, {'文章標題': '奇怪的IPER3測試結果', '標籤': ['iperf', 'iperf3'], '詢問日期': '9月23日'}, {'文章標題': 'python學生程式設計問題', '標籤': ['python3', '大學', '大學作業'], '詢問日期': '9月22日'}, {'文章標題': '電腦自動關機', '標籤': ['電腦自動關機'], '詢問日期': '9月22日'}, {'文章標題': '各瀏覽器行動裝置debug', '標籤': ['web', 'ios', 'android', 'chrome', 'safari'], '詢問日期': '9月22日'}, {'文章標題': '請問JS如何把這個Array修改成Object', '標籤': ['js', 'array', 'object'], '詢問日期': '9月22日'}, {'文章標題': '無法PORT Forwarding', '標籤': ['port forwarding', 'mikrotik', 'router os'], '詢問日期': '9月22日'}, {'文章標題': '[問題]華苓科技 Agentflow BPM系統', '標籤': ['bpm', 'agentflow', '簽核系統'], '詢問日期': '9月22日'}, {'文章標題': 'Global runat server 導致 LineBotSDK 錯誤如何解？', '標籤': ['c#', 'linebotsdk', 'line messaging api', 'global'], '詢問日期': '9月22日'}, {'文章標題': 'vba Format(Now, "HH")問題', '標籤': ['vba', 'excel vba'], '詢問日期': '9月22日'}, {'文章標題': '影像處理', '標籤': ['matlab', '影像處理', '資工'], '詢問日期': '9月22日'}, {'文章標題': '疑似區域網路頻繁中斷', '標籤': ['區域網路'], '詢問日期': '9月22日'}, {'文章標題': '【PYTHON】請問如何避免內容重複抓取', '標籤': ['python入門', 'python'], '詢問日期': '9月22日'}, {'文章標題': 'VS2022多個projects在單一solution分開執行', '標籤': ['visual studio 2022'], '詢問日期': '9月22日'}, {'文章標題': 'SGD', '標籤': ['深度學習', 'stochastic gradient descent algorithm'], '詢問日期': '9月22日'}, {'文章標題': 'Google Apps Script 速度優化問題', '標籤': ['google apps script(gas)'], '詢問日期': '9月22日'}, {'文章標題': '製作APP疑問', '標籤': ['app', 'ios', 'android'], '詢問日期': '9月21日'}, {'文章標題': 'C# DbContext 連線於不同Thread運作問題', '標籤': ['c#', 'thread', 'efcore'], '詢問日期': '9月21日'}, {'文章標題': 'Android 面對不同廠牌與版本的處理辦法？', '標籤': ['android', 'debug', 'root', 'custom rom'], '詢問日期': '9月21日'}, {'文章標題': 'Exchange刪除帳號，不要同步刪除AD帳號', '標籤': ['ex ...

# %%
temp = Data.get('Title') #取得 key = "Title" 的 value 
temp #印出 key = "Title" 的 value
# Out:
# [{'文章標題': 'git 沒反應', '標籤': ['git', 'github'], '詢問日期': '9月24日'},
#  {'文章標題': 'tableau 無法自動更新來源excel資料', '標籤': ['tableau'], '詢問日期': '9月24日'},
#  {'文章標題': '字典列表匯出excel',
#   '標籤': ['大神幫幫我', 'python3', '走不出新手村', '拜託'],
#   '詢問日期': '9月24日'},
#  {'文章標題': 'Excel 如何回傳一組可變的地址範圍，藉此針對該範圍進行數據查找。(修正問題描述)',
#   '標籤': ['excel', 'address', 'data', 'difficult：)'],
#   '詢問日期': '9月24日'},
#  {'文章標題': '在 Mac OS 的 Android Studio 手機模擬器無法開機問題',
#   '標籤': ['android studio', 'android', '手機模擬器', 'mac', 'mac os'],
#   '詢問日期': '9月24日'},
#  {'文章標題': '電腦不時定格 需要手動重啟 是哪裡出問題了?',
#   '標籤': ['當機', '電腦當機', '畫面死當', 'cpu過熱', '電源供應器'],
#   '詢問日期': '9月24日'},
#  {'文章標題': 'PCIe, Ethernet & GPU的Bottleneck',
#   '標籤': ['bottleneck', 'bandwidth', 'gpu'],
#   '詢問日期': '9月24日'},
#  {'文章標題': '如何 在 android studio accessibility service 編寫 設定數字鍵 最後在APP外面 按下數字鍵 回應訊息',
#   '標籤': ['android studio accessibility service'],
#   '詢問日期': '9月23日'},
#  {'文章標題': '如何讓grid item根據剩餘vh自動填滿的高度?',
#   '標籤': ['css', 'grid', 'flex', 'webdesign'],
#   '詢問日期': '9月23日'},
#  {'文章標題': '0fdffffffffffff', '標籤': ['軟體工程師'], '詢問日期': '9月23日'},
#  {'文章標題': '可以問一下 vagrant 這兩種 provider 差在哪',
#   '標籤': ['vagrant'],
#   '詢問日期': '9月23日'},
#  {'文章標題': 'ubuntu 20讀取不到 主機板RAID1', '標籤': ['raid', 'linux'], '詢問日期': '9月23日'},
#  {'文章標題': 'Adobe AI & AE 權限問題,無法開啟',
#   '標籤': ['#adobe', '#adobe illustrator', '#adobe after effects'],
#   '詢問日期': '9月23日'},
#  {'文章標題': '開源的網頁問卷調查系統推薦', '標籤': ['survey'], '詢問日期': '9月23日'},
#  {'文章標題': '開源的網頁問卷調查系統推薦', '標籤': ['limesurvey'], '詢問日期': '9月23日'},
#  {'文章標題': '機房冷氣故障待維修，請教下應急處理', '標籤': ['機房', '散熱', '冷氣故障'], '詢問日期': '9月23日'},
#  {'文章標題': 'VBScript是否有涵式可判斷MSSQL的錯誤',
#   '標籤': ['@vbs', '@asp', '@mssql'],
#   '詢問日期': '9月23日'},
#  {'文章標題': '顯示出重複字串', '標籤': ['python', '數據分析'], '詢問日期': '9月23日'},
#  {'文章標題': 'AD錯誤訊息-本機系統 的自動憑證註冊無法註冊 網域控制站 憑證 (0x80070005) 存取被拒。',
#   '標籤': ['ad', 'windows server 2003'],
#   '詢問日期': '9月23日'},
#  {'文章標題': '[PHP][javascript]定位失效',
#   '標籤': ['#id定位', '#php', '#javascript', '#line分享'],
#   '詢問日期': '9月23日'},
#  {'文章標題': '想把 powershell 的 ctrl+v 的貼上功能停用，卻遇到權限問題(已解決)',
#   '標籤': ['powershell', 'ctrl+v', '停用'],
#   '詢問日期': '9月23日'},
#  {'文章標題': 'html 如何即時檢測到input裡有東西輸入',
#   '標籤': ['html', 'javascript'],
#   '詢問日期': '9月23日'},
#  {'文章標題': '請問有甚麼用arduino做溫室加溫的方法',
#   '標籤': ['加溫', 'arduino', 'arduino加溫控制', '溫室', '致冷晶片'],
#   '詢問日期': '9月23日'},
#  {'文章標題': 'Windows的工作排程器執行無反應',
#   '標籤': ['windows', '#工作排程器', 'bat批次檔'],
#   '詢問日期': '9月23日'},
#  {'文章標題': 'sim卡wifi', '標籤': ['sim卡wifi'], '詢問日期': '9月23日'},
#  {'文章標題': 'vmware migration issue',
#   '標籤': ['vmware', 'netapp', 'migration'],
#   '詢問日期': '9月23日'},
#  {'文章標題': '奇怪的IPER3測試結果', '標籤': ['iperf', 'iperf3'], '詢問日期': '9月23日'},
#  {'文章標題': 'python學生程式設計問題', '標籤': ['python3', '大學', '大學作業'], '詢問日期': '9月22日'},
#  {'文章標題': '電腦自動關機', '標籤': ['電腦自動關機'], '詢問日期': '9月22日'},
#  {'文章標題': '各瀏覽器行動裝置debug',
#   '標籤': ['web', 'ios', 'android', 'chrome', 'safari'],
#   '詢問日期': '9月22日'},
#  {'文章標題': '請問JS如何把這個Array修改成Object',
#   '標籤': ['js', 'array', 'object'],
#   '詢問日期': '9月22日'},
#  {'文章標題': '無法PORT Forwarding',
#   '標籤': ['port forwarding', 'mikrotik', 'router os'],
#   '詢問日期': '9月22日'},
#  {'文章標題': '[問題]華苓科技 Agentflow BPM系統',
#   '標籤': ['bpm', 'agentflow', '簽核系統'],
#   '詢問日期': '9月22日'},
#  {'文章標題': 'Global runat server 導致 LineBotSDK 錯誤如何解？',
#   '標籤': ['c#', 'linebotsdk', 'line messaging api', 'global'],
#   '詢問日期': '9月22日'},
#  {'文章標題': 'vba Format(Now, "HH")問題',
#   '標籤': ['vba', 'excel vba'],
#   '詢問日期': '9月22日'},
#  {'文章標題': '影像處理', '標籤': ['matlab', '影像處理', '資工'], '詢問日期': '9月22日'},
#  {'文章標題': '疑似區域網路頻繁中斷', '標籤': ['區域網路'], '詢問日期': '9月22日'},
#  {'文章標題': '【PYTHON】請問如何避免內容重複抓取',
#   '標籤': ['python入門', 'python'],
#   '詢問日期': '9月22日'},
#  {'文章標題': 'VS2022多個projects在單一solution分開執行',
#   '標籤': ['visual studio 2022'],
#   '詢問日期': '9月22日'},
#  {'文章標題': 'SGD',
#   '標籤': ['深度學習', 'stochastic gradient descent algorithm'],
#   '詢問日期': '9月22日'},
#  {'文章標題': 'Google Apps Script 速度優化問題',
#   '標籤': ['google apps script(gas)'],
#   '詢問日期': '9月22日'},
#  {'文章標題': '製作APP疑問', '標籤': ['app', 'ios', 'android'], '詢問日期': '9月21日'},
#  {'文章標題': 'C# DbContext 連線於不同Thread運作問題',
#   '標籤': ['c#', 'thread', 'efcore'],
#   '詢問日期': '9月21日'},
#  {'文章標題': 'Android 面對不同廠牌與版本的處理辦法？',
#   '標籤': ['android', 'debug', 'root', 'custom rom'],
#   '詢問日期': '9月21日'},
#  {'文章標題': 'Exchange刪除帳號，不要同步刪除AD帳號', '標籤': ['exchange2019'], '詢問日期': '9月21日'},
#  {'文章標題': '混合雲架構下移除Exchange問題',
#   '標籤': ['hybrid', '混合雲', 'exchange server', 'aad connector', 'exchange2016'],
#   '詢問日期': '9月21日'},
#  {'文章標題': 'ERP 廠商詢問', '標籤': ['erp'], '詢問日期': '9月21日'},
#  {'文章標題': 'windows server 應該要開啟哪些稽核功能？',
#   '標籤': ['#windows server', '#稽核功能', '#稽核日誌'],
#   '詢問日期': '9月21日'},
#  {'文章標題': '共用信箱(Shared mailbox)的信件封存',
#   '標籤': ['共用信箱', 'shared mailbox'],
#   '詢問日期': '9月21日'},
#  {'文章標題': '挑選程式開發用筆電',
#   '標籤': ['軟體開發', '開發工具', '筆電型號推薦', '購買'],
#   '詢問日期': '9月21日'},
#  {'文章標題': 'adobe acrobat 列印字型問題', '標籤': ['adobe acrobat'], '詢問日期': '9月21日'},
#  {'文章標題': 'html 跳頁到指定編輯區進行編輯', '標籤': ['html', 'javascript'], '詢問日期': '9月21日'},
#  {'文章標題': 'DHCP 網段', '標籤': ['dhcp'], '詢問日期': '9月21日'},
#  {'文章標題': '請問 k8s core DNS 設定 要怎麼持久化捏', '標籤': ['kubernetes'], '詢問日期': '9月21日'},
#  {'文章標題': 'Mesh路由器 網頁認證',
#   '標籤': ['xampp', '網頁認證', 'mesh', 'getway', '網頁登入'],
#   '詢問日期': '9月20日'},
#  {'文章標題': '我想詢問出百題因式分解的c++程式', '標籤': ['c++'], '詢問日期': '9月20日'},
#  {'文章標題': '硬碟資料無法讀取', '標籤': ['硬碟'], '詢問日期': '9月20日'},
#  {'文章標題': 'ASP.NET Core appsetting.json 加密問題',
#   '標籤': ['asp.net core'],
#   '詢問日期': '9月20日'},
#  {'文章標題': '想請問 &-- 在 SCSS 中代表什麼意思呢？',
#   '標籤': ['scss 架構', 'css', 'sass'],
#   '詢問日期': '9月20日'},
#  {'文章標題': '封包側錄與網路架構', '標籤': ['封包', '網路'], '詢問日期': '9月20日'},
#  {'文章標題': 'webdriver問題，爬不出照片',
#   '標籤': ['python',
#    'selenium webdriver',
#    'crawler',
#    'exception has been thrown'],
#   '詢問日期': '9月20日'},
#  {'文章標題': '有什麼用arduino做水量控制的好方法嗎？',
#   '標籤': ['arduino', '水量控制', '智慧農場', 'iot'],
#   '詢問日期': '9月20日'},
#  {'文章標題': 'C語言四則運算', '標籤': ['c', 'c/c++系列文章', '程式設計'], '詢問日期': '9月20日'},
#  {'文章標題': '請問 excel 該如何知道vba代碼是沒有問題的',
#   '標籤': ['excel', 'excel vba', 'vba'],
#   '詢問日期': '9月20日'},
#  {'文章標題': '建立ASP.NET Core 專案Controller、Model資料夾消失了',
#   '標籤': ['asp.net core'],
#   '詢問日期': '9月20日'},
#  {'文章標題': '請教前輩們一個 GitGraph 套件的問題',
#   '標籤': ['git', 'git graph'],
#   '詢問日期': '9月20日'},
#  {'文章標題': '想詢問方向', '標籤': ['#菜鳥新人'], '詢問日期': '9月20日'},
#  {'文章標題': 'tableau如何設置紅綠燈代替OK/NG ?', '標籤': ['tableau'], '詢問日期': '9月20日'},
#  {'文章標題': '管理AD上的電腦與伺服器所需的權限',
#   '標籤': ['ad', '#active directory', '網域', '權限', '管理者'],
#   '詢問日期': '9月20日'},
#  {'文章標題': 'C語言金字塔', '標籤': ['c', 'c/c++', '程式設計'], '詢問日期': '9月19日'},
#  {'文章標題': 'vs2017/vs2019 軟體設定問題', '標籤': ['軟體設定'], '詢問日期': '9月19日'},
#  {'文章標題': 'VPN使用問題', '標籤': ['vpn'], '詢問日期': '9月19日'},
#  {'文章標題': '關於使用Java進行ETL工作的問題',
#   '標籤': ['java', 'etl', 'data', 'database', 'sql'],
#   '詢問日期': '9月19日'},
#  {'文章標題': '請教學facebook如何看到誰分享我的貼文，照片',
#   '標籤': ['facebook', '分享名單教學'],
#   '詢問日期': '9月19日'},
#  {'文章標題': 'imgur 不會播放',
#   '標籤': ['imgur', 'frontend', 'it14', '鐵人賽', '鐵人'],
#   '詢問日期': '9月19日'},
#  {'文章標題': '[問題] Thunderbird轉用Outlook',
#   '標籤': ['outlook', 'thunderbird', 'pop3', 'email'],
#   '詢問日期': '9月19日'},
#  {'文章標題': '選擇檔案就出現Active元件無法產生物件', '標籤': ['active元件無法產生物件'], '詢問日期': '9月19日'},
#  {'文章標題': '家裡連線到學校xampp', '標籤': ['xampp'], '詢問日期': '9月19日'},
#  {'文章標題': 'Hyper-V匯出虛擬機失敗0x80070005',
#   '標籤': ['hyper-v', 'export'],
#   '詢問日期': '9月19日'},
#  {'文章標題': 'Exam的vce檔案打不開', '標籤': ['exam vce'], '詢問日期': '9月19日'},
#  {'文章標題': 'windows能撰寫、執行swift嗎??', '標籤': ['swift'], '詢問日期': '9月19日'},
#  {'文章標題': 'vscode 和container建立ssh 連線失敗(急)',
#   '標籤': ['vscode', 'ssh'],
#   '詢問日期': '9月18日'},
#  {'文章標題': '計算list多維數量', '標籤': ['python', '計算', '數據分析'], '詢問日期': '9月18日'},
#  {'文章標題': 'txt中 奇怪的字', '標籤': ['txt文字檔', '文字辨識', '文字編碼'], '詢問日期': '9月18日'},
#  {'文章標題': 'Router+L2 switch的vlan dhcp配置方法',
#   '標籤': ['vlan設定', 'dhcp'],
#   '詢問日期': '9月18日'},
#  {'文章標題': 'python: sql 將同筆資料寫入兩個不同表單',
#   '標籤': ['python', 'mysql', 'sqlserver'],
#   '詢問日期': '9月18日'},
#  {'文章標題': '請問一般AD管理，要注意哪些，看那些LOG呢', '標籤': ['ad'], '詢問日期': '9月18日'}]

# %%
dic = {} #紀錄下面取得的不同"標籤"出現次數
for i in temp: #從 list 中一個一個列舉出 dict
    #print(li['標籤'])
    for j in i['標籤']: #列舉出每個 key = "標籤" 的 value
        dic[j] = dic.get(j,0)+1 #檢查"標籤"中的每個字串是否出現在 dic 中。如果沒出現，則加入 dic 裡，並使其 value=1 ; 否則已經出現就將其 value+1
dic #印出不同"標籤"出現次數
# Out:
# {'git': 2,
#  'github': 1,
#  'tableau': 2,
#  '大神幫幫我': 1,
#  'python3': 2,
#  '走不出新手村': 1,
#  '拜託': 1,
#  'excel': 2,
#  'address': 1,
#  'data': 2,
#  'difficult：)': 1,
#  'android studio': 1,
#  'android': 4,
#  '手機模擬器': 1,
#  'mac': 1,
#  'mac os': 1,
#  '當機': 1,
#  '電腦當機': 1,
#  '畫面死當': 1,
#  'cpu過熱': 1,
#  '電源供應器': 1,
#  'bottleneck': 1,
#  'bandwidth': 1,
#  'gpu': 1,
#  'android studio accessibility service': 1,
#  'css': 2,
#  'grid': 1,
#  'flex': 1,
#  'webdesign': 1,
#  '軟體工程師': 1,
#  'vagrant': 1,
#  'raid': 1,
#  'linux': 1,
#  '#adobe': 1,
#  '#adobe illustrator': 1,
#  '#adobe after effects': 1,
#  'survey': 1,
#  'limesurvey': 1,
#  '機房': 1,
#  '散熱': 1,
#  '冷氣故障': 1,
#  '@vbs': 1,
#  '@asp': 1,
#  '@mssql': 1,
#  'python': 5,
#  '數據分析': 2,
#  'ad': 3,
#  'windows server 2003': 1,
#  '#id定位': 1,
#  '#php': 1,
#  '#javascript': 1,
#  '#line分享': 1,
#  'powershell': 1,
#  'ctrl+v': 1,
#  '停用': 1,
#  'html': 2,
#  'javascript': 2,
#  '加溫': 1,
#  'arduino': 2,
#  'arduino加溫控制': 1,
#  '溫室': 1,
#  '致冷晶片': 1,
#  'windows': 1,
#  '#工作排程器': 1,
#  'bat批次檔': 1,
#  'sim卡wifi': 1,
#  'vmware': 1,
#  'netapp': 1,
#  'migration': 1,
#  'iperf': 1,
#  'iperf3': 1,
#  '大學': 1,
#  '大學作業': 1,
#  '電腦自動關機': 1,
#  'web': 1,
#  'ios': 2,
#  'chrome': 1,
#  'safari': 1,
#  'js': 1,
#  'array': 1,
#  'object': 1,
#  'port forwarding': 1,
#  'mikrotik': 1,
#  'router os': 1,
#  'bpm': 1,
#  'agentflow': 1,
#  '簽核系統': 1,
#  'c#': 2,
#  'linebotsdk': 1,
#  'line messaging api': 1,
#  'global': 1,
#  'vba': 2,
#  'excel vba': 2,
#  'matlab': 1,
#  '影像處理': 1,
#  '資工': 1,
#  '區域網路': 1,
#  'python入門': 1,
#  'visual studio 2022': 1,
#  '深度學習': 1,
#  'stochastic gradient descent algorithm': 1,
#  'google apps script(gas)': 1,
#  'app': 1,
#  'thread': 1,
#  'efcore': 1,
#  'debug': 1,
#  'root': 1,
#  'custom rom': 1,
#  'exchange2019': 1,
#  'hybrid': 1,
#  '混合雲': 1,
#  'exchange server': 1,
#  'aad connector': 1,
#  'exchange2016': 1,
#  'erp': 1,
#  '#windows server': 1,
#  '#稽核功能': 1,
#  '#稽核日誌': 1,
#  '共用信箱': 1,
#  'shared mailbox': 1,
#  '軟體開發': 1,
#  '開發工具': 1,
#  '筆電型號推薦': 1,
#  '購買': 1,
#  'adobe acrobat': 1,
#  'dhcp': 2,
#  'kubernetes': 1,
#  'xampp': 2,
#  '網頁認證': 1,
#  'mesh': 1,
#  'getway': 1,
#  '網頁登入': 1,
#  'c++': 1,
#  '硬碟': 1,
#  'asp.net core': 2,
#  'scss 架構': 1,
#  'sass': 1,
#  '封包': 1,
#  '網路': 1,
#  'selenium webdriver': 1,
#  'crawler': 1,
#  'exception has been thrown': 1,
#  '水量控制': 1,
#  '智慧農場': 1,
#  'iot': 1,
#  'c': 2,
#  'c/c++系列文章': 1,
#  '程式設計': 2,
#  'git graph': 1,
#  '#菜鳥新人': 1,
#  '#active directory': 1,
#  '網域': 1,
#  '權限': 1,
#  '管理者': 1,
#  'c/c++': 1,
#  '軟體設定': 1,
#  'vpn': 1,
#  'java': 1,
#  'etl': 1,
#  'database': 1,
#  'sql': 1,
#  'facebook': 1,
#  '分享名單教學': 1,
#  'imgur': 1,
#  'frontend': 1,
#  'it14': 1,
#  '鐵人賽': 1,
#  '鐵人': 1,
#  'outlook': 1,
#  'thunderbird': 1,
#  'pop3': 1,
#  'email': 1,
#  'active元件無法產生物件': 1,
#  'hyper-v': 1,
#  'export': 1,
#  'exam vce': 1,
#  'swift': 1,
#  'vscode': 1,
#  'ssh': 1,
#  '計算': 1,
#  'txt文字檔': 1,
#  '文字辨識': 1,
#  '文字編碼': 1,
#  'vlan設定': 1,
#  'mysql': 1,
#  'sqlserver': 1}

# %%
#找出最常出現的"標籤"
id = 0 #下面 li_key 和 li_value 的索引值
count = 0 #紀錄現在讀取道第n筆的資料
max = 0 #為了找出最常出現的"標籤"
li_key = []
li_value = []
for i in dic:
    li_key.append(i) #將每個標籤名稱加入 list 中
    li_value.append(dic[i]) #將每個標籤出現過的次數加入 list 中
    if dic[i]>max: #確認是否為最常出現的"標籤"
        max = dic[i]
        id = count
    count+=1
print("最常出現的標籤 :",li_key[id],", 出現",li_value[id],"次")
# Out:
# 最常出現的標籤 : python , 出現 5 次
